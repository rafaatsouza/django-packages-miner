# %%
import pandas as pd
import matplotlib.pyplot as plt

from visualization_methods import VisualizationMethods as vm
import data_methods as dm

df = dm.get_defined_dataframe()
df = df[df['repo_maybe_deprecated']]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 10))
fig.set_facecolor('white')

categories = 'apps', 'frameworks'
platforms = 'github', 'gitlab'

sizes = [
    len(df[df['dp_category'] == categories[0]]),
    len(df[df['dp_category'] == categories[1]]),    
]

vm.set_pie_by_ax(ax1, sizes, categories, 'Django Packages Categories')

sizes = [
    len(df[df['platform'] == platforms[0]]),
    len(df[df['platform'] == platforms[1]]),    
]

vm.set_pie_by_ax(ax2, sizes, platforms, 'Django Packages Platforms')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 8))

vm.set_boxplot_by_ax(ax, df['repo_stars'].values, 'Stars Count', True, True)

plt.tight_layout()
plt.show()

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', None)
pd.set_option("display.expand_frame_repr", False)

df[['repo_id', 'dp_repo_url', 'repo_stars', 'dp_category', 'dp_grids']].sort_values(by=['repo_stars'], ascending=False)
# Out:
#                                                  repo_id                                                            dp_repo_url  repo_stars dp_category                                                       dp_grids
# 128                                      django/channels                                     https://github.com/django/channels      5252.0        apps                                                     websockets
# 3094                             omab/django-social-auth                             https://github.com/omab/django-social-auth      2614.0        apps            authentication,facebook-authentication,openid,oauth
# 2788                     marcgibbons/django-rest-swagger                     https://github.com/marcgibbons/django-rest-swagger      2556.0        apps                    django-rest-framework,drf-api-documentation
# 2706                              Tivix/django-rest-auth                              https://github.com/Tivix/django-rest-auth      2312.0        apps                                            rest,authentication
# 2829                                        rq/django-rq                                        https://github.com/rq/django-rq      1508.0        apps                   workers-queues-tasks,celery-vs-djangoq-vs-rq
# 471                                 jrief/django-angular                                https://github.com/jrief/django-angular      1241.0  frameworks                                                      angularjs
# 669                        dyve/django-bootstrap-toolkit                       https://github.com/dyve/django-bootstrap-toolkit      1036.0        apps                                              twitter-bootstrap
# 2757       RealmTeam/django-rest-framework-social-oauth2       https://github.com/RealmTeam/django-rest-framework-social-oauth2       995.0        apps                           django-rest-framework,authentication
# 975                                    Tivix/django-cron                                   https://github.com/Tivix/django-cron       800.0        apps                                                           cron
# 2733               philipn/django-rest-framework-filters               https://github.com/philipn/django-rest-framework-filters       754.0        apps                                          django-rest-framework
# 3341                                 shacker/django-todo                                 https://github.com/shacker/django-todo       683.0        apps                                             ticketing,calendar
# 1907                           django/django-localflavor                           https://github.com/django/django-localflavor       683.0        apps                                             globalization,i18n
# 2768                            zapier/django-rest-hooks                            https://github.com/zapier/django-rest-hooks       542.0        apps                                                       webhooks
# 2313                        timmyomahony/django-pagedown                        https://github.com/timmyomahony/django-pagedown       540.0        apps                                        wysiwyg,fields,markdown
# 767                               chartit/django-chartit                              https://github.com/chartit/django-chartit       493.0        apps                                   charts,business-intelligence
# 1838                             zapier/django-knowledge                             https://github.com/zapier/django-knowledge       482.0        apps                                            help-desk,ticketing
# 2894                                carljm/django-secure                                https://github.com/carljm/django-secure       473.0        apps                                                       security
# 3611                              pydanny/django-wysiwyg                              https://github.com/pydanny/django-wysiwyg       468.0        apps                                                  forms,wysiwyg
# 1633                            etianen/django-herokuapp                            https://github.com/etianen/django-herokuapp       429.0        apps                                                            NaN
# 2619                              dcramer/django-ratings                              https://github.com/dcramer/django-ratings       405.0        apps                                                         rating
# 2495                          Bearle/django-private-chat                          https://github.com/Bearle/django-private-chat       403.0        apps                                      chat,websockets,messaging
# 2401            tbicr/django-pg-zero-downtime-migrations            https://github.com/tbicr/django-pg-zero-downtime-migrations       392.0        apps                                                            NaN
# 2016                                mtigas/django-medusa                                https://github.com/mtigas/django-medusa       333.0        apps                                                            NaN
# 3732                                      brack3t/Djrill                                      https://github.com/brack3t/Djrill       329.0        apps                                            email,incomingemail
# 2369                          jazzband/django-permission                          https://github.com/jazzband/django-permission       299.0  frameworks                                  authentication,perms,security
# 1813                        jmrivas86/django-json-widget                        https://github.com/jmrivas86/django-json-widget       285.0        apps  json-fields,admin-addons,fields,admin-styling,admin-interface
# 2024                       bartTC/django-memcache-status                       https://github.com/bartTC/django-memcache-status       267.0        apps                                                            NaN
# 1246                    dabapps/django-email-as-username                    https://github.com/dabapps/django-email-as-username       263.0        apps                                           authentication,email
# 1770                stephenmuss/django-ios-notifications                https://github.com/stephenmuss/django-ios-notifications       229.0        apps                                                            NaN
# 3644                                dmgctrl/django-ztask                                https://github.com/dmgctrl/django-ztask       224.0        apps                                           workers-queues-tasks
# 661                 jmcclell/django-bootstrap-pagination                https://github.com/jmcclell/django-bootstrap-pagination       216.0        apps                                                     pagination
# 891                                  Tivix/django-common                                 https://github.com/Tivix/django-common       214.0        apps                                                            NaN
# 4215                                        disqus/nexus                                        https://github.com/disqus/nexus       208.0        apps                                                admin-interface
# 1480                         bartTC/django-frontendadmin                         https://github.com/bartTC/django-frontendadmin       190.0        apps                               admin-interface,frontend-editing
# 3787                                limdauto/drf_openapi                                https://github.com/limdauto/drf_openapi       189.0        apps                                          django-rest-framework
# 3638                              GoodCloud/django-zebra                              https://github.com/GoodCloud/django-zebra       185.0        apps                                      payment-processing,stripe
# 2214                          relekang/django-nopassword                          https://github.com/relekang/django-nopassword       181.0        apps                                                 authentication
# 4028                                       jbalogh/jingo                                       https://github.com/jbalogh/jingo       178.0        apps               template-engine-adapters,jinja2-template-loaders
# 3222                            shymonk/django-datatable                            https://github.com/shymonk/django-datatable       169.0        apps                                          tables,django-tables2
# 1491                             jazzband/django-fsm-log                             https://github.com/jazzband/django-fsm-log       168.0        apps                                                            NaN
# 2551                               rakanalh/django-pushy                               https://github.com/rakanalh/django-pushy       168.0        apps                                                            NaN
# 408                   ctxis/django-admin-view-permission                  https://github.com/ctxis/django-admin-view-permission       150.0        apps                                          perms,admin-interface
# 1409                       alex/django-fixture-generator                       https://github.com/alex/django-fixture-generator       139.0        apps                                                       fixtures
# 1351                          peterbe/django-fancy-cache                          https://github.com/peterbe/django-fancy-cache       138.0        apps                                                        caching
# 1128                       jezdez/django-discover-runner                       https://github.com/jezdez/django-discover-runner       135.0        apps                                                            NaN
# 2297                    django-oscar/django-oscar-paypal                    https://github.com/django-oscar/django-oscar-paypal       133.0        apps                                                            NaN
# 3334                        romanvm/django-tinymce4-lite                        https://github.com/romanvm/django-tinymce4-lite       129.0        apps                                                        wysiwyg
# 3160                           jezdez/django-staticfiles                           https://github.com/jezdez/django-staticfiles       127.0        apps                                 asset-managers,static-builders
# 4420                                         salad/salad                                         https://github.com/salad/salad       125.0        apps                                                        testing
# 3793                      wagnerdelima/drf-social-oauth2                      https://github.com/wagnerdelima/drf-social-oauth2       121.0        apps                      rest,django-rest-framework,authentication
# 1033                         tolomea/django-data-browser                         https://github.com/tolomea/django-data-browser       120.0        apps                                                      reporting
# 3123                            acdha/django-speedtracer                            https://github.com/acdha/django-speedtracer       120.0        apps                                                      analytics
# 2071                           jezdez/django-mobileadmin                           https://github.com/jezdez/django-mobileadmin       118.0        apps                                                         mobile
# 3345                                  jedie/django-tools                                  https://github.com/jedie/django-tools       115.0        apps                                                developer-tools
# 4353                 python-thumbnails/python-thumbnails                 https://github.com/python-thumbnails/python-thumbnails       110.0        apps                                              thumbnails,photos
# 3852                                pinax/pinax-eventlog                                https://github.com/pinax/pinax-eventlog       108.0        apps                                                            NaN
# 1869                 umap-project/django-leaflet-storage                 https://github.com/umap-project/django-leaflet-storage       107.0        apps                                                           maps
# 3858  JamesRitchie/django-rest-framework-expiring-tokens  https://github.com/JamesRitchie/django-rest-framework-expiring-tokens       106.0        apps                                          django-rest-framework
# 4043                             pinax/pinax-invitations                             https://github.com/pinax/pinax-invitations       106.0        apps                                                            NaN
